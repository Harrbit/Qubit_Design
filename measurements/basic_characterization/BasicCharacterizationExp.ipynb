# %% [markdown]
# # Import BasicCharacterization and supporting package

# %%
from laboneq.simple import *
import matplotlib.pyplot as plt
import numpy as np
import laboneq

import sys
import os

import importlib.util

from laboneq.contrib.example_helpers.plotting.plot_helpers import plot_simulation

module_name = "BasicCharacterization"
module_file = "BasicCharacterization.py"

spec = importlib.util.spec_from_file_location(module_name, module_file)
if spec is not None:
    module = importlib.util.module_from_spec(spec)
    sys.modules[module_name] = module
    try:
        spec.loader.exec_module(module)
        # Import all classes from the module
        for attr_name in dir(module):
            attr = getattr(module, attr_name)
            if isinstance(attr, type):
                globals()[attr_name] = attr
    except Exception as e:
        print(f"Failed to import {module_file}: {e}")
else:
    print(f"Could not find module spec for {module_file}")

# %% [markdown]
# # Do Resonator Spectroscopy

# %%
instance_ResSpec = ResSpec()
data_ResSpec = instance_ResSpec.run_experiment()
plot_simulation(instance_ResSpec.compiled_exp_instance, 0, 100e-6)
# Out:
# 2.57.0
# [2025.08.21 16:07:03.740] INFO    Logging initialized from [Default inline config in laboneq.laboneq_logging] logdir is c:\Users\24716\Documents\code\python\qubit_design\measurements\basic_characterization\laboneq_output\log
# [2025.08.21 16:07:03.752] INFO    VERSION: laboneq 2.57.0
# [2025.08.21 16:07:03.755] INFO    Connecting to data server at 127.0.0.1:8004
# [2025.08.21 16:07:03.757] INFO    Connected to Zurich Instruments LabOne Data Server version 25.07.0.507 at 127.0.0.1:8004
# [2025.08.21 16:07:03.761] INFO    Configuring the device setup
# [2025.08.21 16:07:03.763] INFO    The device setup is configured
# [2025.08.21 16:07:03.766] INFO    Starting LabOne Q Compiler run...
# [2025.08.21 16:07:03.994] INFO    Schedule completed. [0.225 s]
# [2025.08.21 16:07:04.904] INFO    Code generation completed for all AWGs. [0.910 s]
# [2025.08.21 16:07:04.904] INFO    Completed compilation step 1 of 1. [1.137 s]
# [2025.08.21 16:07:04.904] INFO     ──────────────────────────────────────────────────────────────────
# [2025.08.21 16:07:04.904] INFO      Device         AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2025.08.21 16:07:04.904] INFO     ──────────────────────────────────────────────────────────────────
# [2025.08.21 16:07:04.904] INFO      device_shfqc     0         19            0           1      4000
# [2025.08.21 16:07:04.904] INFO     ──────────────────────────────────────────────────────────────────
# [2025.08.21 16:07:04.904] INFO      TOTAL                      19            0                  4000
# [2025.08.21 16:07:04.904] INFO     ──────────────────────────────────────────────────────────────────
# [2025.08.21 16:07:04.920] INFO    Finished LabOne Q Compiler run.
# [2025.08.21 16:07:04.924] INFO    Starting near-time execution...
# [2025.08.21 16:07:04.924] INFO    Finished near-time execution.

# %%
data_ResSpec.waves
# Out:
# {'p_2000_readout_pulse_00_a0100_l2000_sc0_ap0000_9e3121d.wave': CodegenWaveform(samples=array([0.10000002+0.j, 0.10000002+0.j, 0.10000002+0.j, ...,
#         0.10000002+0.j, 0.10000002+0.j, 0.10000002+0.j], shape=(2000,)), hold_start=None, hold_length=None, downsampling_factor=None)}

# %% [markdown]
# # Do Punchout

# %%
instance_PunchOut = PunchOut()
data_punchout = instance_PunchOut.run_experiment()
# Out:
# 2.57.0
# [2025.08.21 16:07:05.127] INFO    Logging initialized from [Default inline config in laboneq.laboneq_logging] logdir is c:\Users\24716\Documents\code\python\qubit_design\measurements\basic_characterization\laboneq_output\log
# [2025.08.21 16:07:05.131] INFO    VERSION: laboneq 2.57.0
# [2025.08.21 16:07:05.132] INFO    Connecting to data server at 127.0.0.1:8004
# [2025.08.21 16:07:05.134] INFO    Connected to Zurich Instruments LabOne Data Server version 25.07.0.507 at 127.0.0.1:8004
# [2025.08.21 16:07:05.138] INFO    Configuring the device setup
# [2025.08.21 16:07:05.139] INFO    The device setup is configured
# LinearSweepParameter(
# │   uid='acquisition_amplitude_sweep',
# │   start=0.1,
# │   stop=0.7,
# │   count=11,
# │   axis_name=None
# )
#
# [2025.08.21 16:07:05.144] INFO    Starting LabOne Q Compiler run...
# [2025.08.21 16:07:05.370] INFO    Schedule completed. [0.223 s]
# [2025.08.21 16:07:05.823] INFO    Code generation completed for all AWGs. [0.452 s]
# [2025.08.21 16:07:05.824] INFO    Completed compilation step 1 of 11. [0.677 s]
# [2025.08.21 16:07:06.161] INFO    Schedule completed. [0.341 s]
# [2025.08.21 16:07:06.458] INFO    Code generation completed for all AWGs. [0.292 s]
# [2025.08.21 16:07:06.459] INFO    Completed compilation step 2 of 11. [0.635 s]
# [2025.08.21 16:07:06.819] INFO    Schedule completed. [0.359 s]
# [2025.08.21 16:07:07.261] INFO    Code generation completed for all AWGs. [0.440 s]
# [2025.08.21 16:07:07.262] INFO    Completed compilation step 3 of 11. [0.802 s]
# [2025.08.21 16:07:07.480] INFO    Schedule completed. [0.220 s]
# [2025.08.21 16:07:07.930] INFO    Code generation completed for all AWGs. [0.447 s]
# [2025.08.21 16:07:07.930] INFO    Completed compilation step 4 of 11. [0.669 s]
# [2025.08.21 16:07:08.154] INFO    Schedule completed. [0.221 s]
# [2025.08.21 16:07:08.631] INFO    Code generation completed for all AWGs. [0.484 s]
# [2025.08.21 16:07:08.641] INFO    Completed compilation step 5 of 11. [0.708 s]
# [2025.08.21 16:07:08.874] INFO    Schedule completed. [0.233 s]
# [2025.08.21 16:07:09.365] INFO    Code generation completed for all AWGs. [0.491 s]
# [2025.08.21 16:07:09.365] INFO    Completed compilation step 6 of 11. [0.726 s]
# [2025.08.21 16:07:09.575] INFO    Schedule completed. [0.219 s]
# [2025.08.21 16:07:09.867] INFO    Code generation completed for all AWGs. [0.282 s]
# [2025.08.21 16:07:09.867] INFO    Completed compilation step 7 of 11. [0.504 s]
# [2025.08.21 16:07:10.326] INFO    Schedule completed. [0.459 s]
# [2025.08.21 16:07:10.610] INFO    Code generation completed for all AWGs. [0.283 s]
# [2025.08.21 16:07:10.610] INFO    Completed compilation step 8 of 11. [0.745 s]
# [2025.08.21 16:07:10.842] INFO    Schedule completed. [0.221 s]
# [2025.08.21 16:07:11.395] INFO    Code generation completed for all AWGs. [0.561 s]
# [2025.08.21 16:07:11.395] INFO    Completed compilation step 9 of 11. [0.786 s]
# [2025.08.21 16:07:11.629] INFO    Schedule completed. [0.222 s]
# [2025.08.21 16:07:11.916] INFO    Code generation completed for all AWGs. [0.286 s]
# [2025.08.21 16:07:11.917] INFO    Completed compilation step 10 of 11. [0.511 s]
# [2025.08.21 16:07:12.471] INFO    Schedule completed. [0.553 s]
# [2025.08.21 16:07:12.744] INFO    Code generation completed for all AWGs. [0.284 s]
# [2025.08.21 16:07:12.744] INFO    Completed compilation step 11 of 11. [0.840 s]
# [2025.08.21 16:07:12.768] INFO     ─────────────────────────────────────────────────────────────────────────
# [2025.08.21 16:07:12.768] INFO      Step   Device         AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2025.08.21 16:07:12.768] INFO     ─────────────────────────────────────────────────────────────────────────
# [2025.08.21 16:07:12.772] INFO      0      device_shfqc     0         19            0           1      4000
# [2025.08.21 16:07:12.773] INFO     ─────────────────────────────────────────────────────────────────────────
# [2025.08.21 16:07:12.773] INFO      1      device_shfqc     0         19            0           1      4000
# [2025.08.21 16:07:12.774] INFO     ─────────────────────────────────────────────────────────────────────────
# [2025.08.21 16:07:12.775] INFO      2      device_shfqc     0         19            0           1      4000
# [2025.08.21 16:07:12.776] INFO     ─────────────────────────────────────────────────────────────────────────
# [2025.08.21 16:07:12.776] INFO      3      device_shfqc     0         19            0           1      4000
# [2025.08.21 16:07:12.776] INFO     ─────────────────────────────────────────────────────────────────────────
# [2025.08.21 16:07:12.778] INFO      4      device_shfqc     0         19            0           1      4000
# [2025.08.21 16:07:12.779] INFO     ─────────────────────────────────────────────────────────────────────────
# [2025.08.21 16:07:12.779] INFO      5      device_shfqc     0         19            0           1      4000
# [2025.08.21 16:07:12.780] INFO     ─────────────────────────────────────────────────────────────────────────
# [2025.08.21 16:07:12.780] INFO      6      device_shfqc     0         19            0           1      4000
# [2025.08.21 16:07:12.781] INFO     ─────────────────────────────────────────────────────────────────────────
# [2025.08.21 16:07:12.781] INFO      7      device_shfqc     0         19            0           1      4000
# [2025.08.21 16:07:12.782] INFO     ─────────────────────────────────────────────────────────────────────────
# [2025.08.21 16:07:12.783] INFO      8      device_shfqc     0         19            0           1      4000
# [2025.08.21 16:07:12.783] INFO     ─────────────────────────────────────────────────────────────────────────
# [2025.08.21 16:07:12.784] INFO      9      device_shfqc     0         19            0           1      4000
# [2025.08.21 16:07:12.784] INFO     ─────────────────────────────────────────────────────────────────────────
# [2025.08.21 16:07:12.785] INFO      10     device_shfqc     0         19            0           1      4000
# [2025.08.21 16:07:12.785] INFO     ─────────────────────────────────────────────────────────────────────────
# [2025.08.21 16:07:12.786] INFO             TOTAL                     209            0                 44000
# [2025.08.21 16:07:12.787] INFO     ─────────────────────────────────────────────────────────────────────────
# [2025.08.21 16:07:12.801] INFO    Finished LabOne Q Compiler run.
# [2025.08.21 16:07:12.803] INFO    Starting near-time execution...
# [2025.08.21 16:07:12.845] INFO    Finished near-time execution.

# %%
plot_simulation(instance_PunchOut.compiled_exp_instance, 0, 100e-6)

# %%
data_punchout.waves
# Out:
# {'p_2000_readout_pulse_00_a0100_l2000_sc0_ap0000_9e3121d.wave': CodegenWaveform(samples=array([0.10000002+0.j, 0.10000002+0.j, 0.10000002+0.j, ...,
#         0.10000002+0.j, 0.10000002+0.j, 0.10000002+0.j], shape=(2000,)), hold_start=None, hold_length=None, downsampling_factor=None),
#  'p_2000_readout_pulse_00_a0160_l2000_sc0_ap0000_2f3155c.wave': CodegenWaveform(samples=array([0.16000003+0.j, 0.16000003+0.j, 0.16000003+0.j, ...,
#         0.16000003+0.j, 0.16000003+0.j, 0.16000003+0.j], shape=(2000,)), hold_start=None, hold_length=None, downsampling_factor=None),
#  'p_2000_readout_pulse_00_a0220_l2000_sc0_ap0000_982d4e9.wave': CodegenWaveform(samples=array([0.22000003+0.j, 0.22000003+0.j, 0.22000003+0.j, ...,
#         0.22000003+0.j, 0.22000003+0.j, 0.22000003+0.j], shape=(2000,)), hold_start=None, hold_length=None, downsampling_factor=None),
#  'p_2000_readout_pulse_00_a0280_l2000_sc0_ap0000_7f3184f.wave': CodegenWaveform(samples=array([0.27999997+0.j, 0.27999997+0.j, 0.27999997+0.j, ...,
#         0.27999997+0.j, 0.27999997+0.j, 0.27999997+0.j], shape=(2000,)), hold_start=None, hold_length=None, downsampling_factor=None),
#  'p_2000_readout_pulse_00_a0340_l2000_sc0_ap0000_ee0e48f.wave': CodegenWaveform(samples=array([0.33999997+0.j, 0.33999997+0.j, 0.33999997+0.j, ...,
#         0.33999997+0.j, 0.33999997+0.j, 0.33999997+0.j], shape=(2000,)), hold_start=None, hold_length=None, downsampling_factor=None),
#  'p_2000_readout_pulse_00_a0400_l2000_sc0_ap0000_e5956b6.wave': CodegenWaveform(samples=array([0.39999998+0.j, 0.39999998+0.j, 0.39999998+0.j, ...,
#         0.39999998+0.j, 0.39999998+0.j, 0.39999998+0.j], shape=(2000,)), hold_start=None, hold_length=None, downsampling_factor=None),
#  'p_2000_readout_pulse_00_a0460_l2000_sc0_ap0000_aa3a746.wave': CodegenWaveform(samples=array([0.45999998+0.j, 0.45999998+0.j, 0.45999998+0.j, ...,
#         0.45999998+0.j, 0.45999998+0.j, 0.45999998+0.j], shape=(2000,)), hold_start=None, hold_length=None, downsampling_factor=None),
#  'p_2000_readout_pulse_00_a0520_l2000_sc0_ap0000_0f8fa49.wave': CodegenWaveform(samples=array([0.51999998+0.j, 0.51999998+0.j, 0.51999998+0.j, ...,
#         0.51999998+0.j, 0.51999998+0.j, 0.51999998+0.j], shape=(2000,)), hold_start=None, hold_length=None, downsampling_factor=None),
#  'p_2000_readout_pulse_00_a0580_l2000_sc0_ap0000_dee7687.wave': CodegenWaveform(samples=array([0.57999998+0.j, 0.57999998+0.j, 0.57999998+0.j, ...,
#         0.57999998+0.j, 0.57999998+0.j, 0.57999998+0.j], shape=(2000,)), hold_start=None, hold_length=None, downsampling_factor=None),
#  'p_2000_readout_pulse_00_a0640_l2000_sc0_ap0000_9b20c2c.wave': CodegenWaveform(samples=array([0.63999999+0.j, 0.63999999+0.j, 0.63999999+0.j, ...,
#         0.63999999+0.j, 0.63999999+0.j, 0.63999999+0.j], shape=(2000,)), hold_start=None, hold_length=None, downsampling_factor=None),
#  'p_2000_readout_pulse_00_a0700_l2000_sc0_ap0000_2ea377b.wave': CodegenWaveform(samples=array([0.69999999+0.j, 0.69999999+0.j, 0.69999999+0.j, ...,
#         0.69999999+0.j, 0.69999999+0.j, 0.69999999+0.j], shape=(2000,)), hold_start=None, hold_length=None, downsampling_factor=None)}
