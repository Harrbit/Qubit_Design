# %% [markdown]
# # Import BasicCharacterization and supporting package

# %%
from laboneq.simple import *
import matplotlib.pyplot as plt
import numpy as np
import laboneq

import sys
import os

import importlib.util

from laboneq.contrib.example_helpers.plotting.plot_helpers import plot_simulation

module_name = "BasicCharacterization"
module_file = "BasicCharacterization.py"

spec = importlib.util.spec_from_file_location(module_name, module_file)
if spec is not None:
    module = importlib.util.module_from_spec(spec)
    sys.modules[module_name] = module
    try:
        spec.loader.exec_module(module)
        # Import all classes from the module
        for attr_name in dir(module):
            attr = getattr(module, attr_name)
            if isinstance(attr, type):
                globals()[attr_name] = attr
    except Exception as e:
        print(f"Failed to import {module_file}: {e}")
else:
    print(f"Could not find module spec for {module_file}")

# %% [markdown]
# # Do Resonator Spectroscopy

# %%
instance_ResSpec = ResSpec()
data_ResSpec = instance_ResSpec.run_experiment()
plot_simulation(instance_ResSpec.compiled_exp_instance, 0, 100e-6)
# Out:
# 2.57.0
# [2025.08.21 16:20:05.909] INFO    Logging initialized from [Default inline config in laboneq.laboneq_logging] logdir is /Users/runzhaoguo/Documents/MQST-UCLA/qubit_design/measurements/basic_characterization/laboneq_output/log
# [2025.08.21 16:20:05.911] INFO    VERSION: laboneq 2.57.0
# [2025.08.21 16:20:05.912] INFO    Connecting to data server at 127.0.0.1:8004
# [2025.08.21 16:20:05.913] INFO    Connected to Zurich Instruments LabOne Data Server version 25.07.0.507 at 127.0.0.1:8004
# [2025.08.21 16:20:05.915] INFO    Configuring the device setup
# [2025.08.21 16:20:05.917] INFO    The device setup is configured
# [2025.08.21 16:20:05.920] INFO    Starting LabOne Q Compiler run...
# [2025.08.21 16:20:06.028] INFO    Schedule completed. [0.106 s]
# [2025.08.21 16:20:06.170] INFO    Code generation completed for all AWGs. [0.141 s]
# [2025.08.21 16:20:06.170] INFO    Completed compilation step 1 of 1. [0.248 s]
# [2025.08.21 16:20:06.171] INFO     ──────────────────────────────────────────────────────────────────
# [2025.08.21 16:20:06.171] INFO      Device         AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2025.08.21 16:20:06.172] INFO     ──────────────────────────────────────────────────────────────────
# [2025.08.21 16:20:06.172] INFO      device_shfqc     0         19            0           1      4000
# [2025.08.21 16:20:06.172] INFO     ──────────────────────────────────────────────────────────────────
# [2025.08.21 16:20:06.172] INFO      TOTAL                      19            0                  4000
# [2025.08.21 16:20:06.172] INFO     ──────────────────────────────────────────────────────────────────
# [2025.08.21 16:20:06.184] INFO    Finished LabOne Q Compiler run.
# [2025.08.21 16:20:06.188] INFO    Starting near-time execution...
# [2025.08.21 16:20:06.191] INFO    Finished near-time execution.

# %%
data_ResSpec.waves
# Out:
# {'p_2000_readout_pulse_00_a0100_l2000_sc0_ap0000_9e3121d.wave': CodegenWaveform(samples=array([0.10000002+0.j, 0.10000002+0.j, 0.10000002+0.j, ...,
#         0.10000002+0.j, 0.10000002+0.j, 0.10000002+0.j], shape=(2000,)), hold_start=None, hold_length=None, downsampling_factor=None)}

# %% [markdown]
# # Do Punchout

# %%
instance_PunchOut = PunchOut()
data_punchout = instance_PunchOut.run_experiment()
# Out:
# 2.57.0
# [2025.08.21 16:20:06.365] INFO    Logging initialized from [Default inline config in laboneq.laboneq_logging] logdir is /Users/runzhaoguo/Documents/MQST-UCLA/qubit_design/measurements/basic_characterization/laboneq_output/log
# [2025.08.21 16:20:06.368] INFO    VERSION: laboneq 2.57.0
# [2025.08.21 16:20:06.371] INFO    Connecting to data server at 127.0.0.1:8004
# [2025.08.21 16:20:06.374] INFO    Connected to Zurich Instruments LabOne Data Server version 25.07.0.507 at 127.0.0.1:8004
# [2025.08.21 16:20:06.377] INFO    Configuring the device setup
# [2025.08.21 16:20:06.379] INFO    The device setup is configured
# LinearSweepParameter(
# │   uid='acquisition_amplitude_sweep',
# │   start=0.1,
# │   stop=0.7,
# │   count=11,
# │   axis_name=None
# )
#
# [2025.08.21 16:20:06.384] INFO    Starting LabOne Q Compiler run...
# [2025.08.21 16:20:06.447] INFO    Schedule completed. [0.061 s]
# [2025.08.21 16:20:06.607] INFO    Code generation completed for all AWGs. [0.159 s]
# [2025.08.21 16:20:06.607] INFO    Completed compilation step 1 of 11. [0.221 s]
# [2025.08.21 16:20:06.720] INFO    Schedule completed. [0.113 s]
# [2025.08.21 16:20:06.809] INFO    Code generation completed for all AWGs. [0.088 s]
# [2025.08.21 16:20:06.810] INFO    Completed compilation step 2 of 11. [0.202 s]
# [2025.08.21 16:20:06.938] INFO    Schedule completed. [0.128 s]
# [2025.08.21 16:20:07.105] INFO    Code generation completed for all AWGs. [0.167 s]
# [2025.08.21 16:20:07.106] INFO    Completed compilation step 3 of 11. [0.296 s]
# [2025.08.21 16:20:07.164] INFO    Schedule completed. [0.058 s]
# [2025.08.21 16:20:07.345] INFO    Code generation completed for all AWGs. [0.180 s]
# [2025.08.21 16:20:07.345] INFO    Completed compilation step 4 of 11. [0.239 s]
# [2025.08.21 16:20:07.403] INFO    Schedule completed. [0.058 s]
# [2025.08.21 16:20:07.597] INFO    Code generation completed for all AWGs. [0.194 s]
# [2025.08.21 16:20:07.598] INFO    Completed compilation step 5 of 11. [0.253 s]
# [2025.08.21 16:20:07.656] INFO    Schedule completed. [0.058 s]
# [2025.08.21 16:20:07.745] INFO    Code generation completed for all AWGs. [0.089 s]
# [2025.08.21 16:20:07.746] INFO    Completed compilation step 6 of 11. [0.148 s]
# [2025.08.21 16:20:07.922] INFO    Schedule completed. [0.176 s]
# [2025.08.21 16:20:08.011] INFO    Code generation completed for all AWGs. [0.089 s]
# [2025.08.21 16:20:08.011] INFO    Completed compilation step 7 of 11. [0.265 s]
# [2025.08.21 16:20:08.212] INFO    Schedule completed. [0.201 s]
# [2025.08.21 16:20:08.300] INFO    Code generation completed for all AWGs. [0.087 s]
# [2025.08.21 16:20:08.301] INFO    Completed compilation step 8 of 11. [0.289 s]
# [2025.08.21 16:20:08.359] INFO    Schedule completed. [0.058 s]
# [2025.08.21 16:20:08.606] INFO    Code generation completed for all AWGs. [0.247 s]
# [2025.08.21 16:20:08.607] INFO    Completed compilation step 9 of 11. [0.305 s]
# [2025.08.21 16:20:08.665] INFO    Schedule completed. [0.058 s]
# [2025.08.21 16:20:08.753] INFO    Code generation completed for all AWGs. [0.088 s]
# [2025.08.21 16:20:08.753] INFO    Completed compilation step 10 of 11. [0.146 s]
# [2025.08.21 16:20:08.812] INFO    Schedule completed. [0.058 s]
# [2025.08.21 16:20:09.087] INFO    Code generation completed for all AWGs. [0.274 s]
# [2025.08.21 16:20:09.087] INFO    Completed compilation step 11 of 11. [0.334 s]
# [2025.08.21 16:20:09.090] INFO     ─────────────────────────────────────────────────────────────────────────
# [2025.08.21 16:20:09.090] INFO      Step   Device         AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2025.08.21 16:20:09.091] INFO     ─────────────────────────────────────────────────────────────────────────
# [2025.08.21 16:20:09.091] INFO      0      device_shfqc     0         19            0           1      4000
# [2025.08.21 16:20:09.091] INFO     ─────────────────────────────────────────────────────────────────────────
# [2025.08.21 16:20:09.091] INFO      1      device_shfqc     0         19            0           1      4000
# [2025.08.21 16:20:09.092] INFO     ─────────────────────────────────────────────────────────────────────────
# [2025.08.21 16:20:09.092] INFO      2      device_shfqc     0         19            0           1      4000
# [2025.08.21 16:20:09.092] INFO     ─────────────────────────────────────────────────────────────────────────
# [2025.08.21 16:20:09.092] INFO      3      device_shfqc     0         19            0           1      4000
# [2025.08.21 16:20:09.092] INFO     ─────────────────────────────────────────────────────────────────────────
# [2025.08.21 16:20:09.093] INFO      4      device_shfqc     0         19            0           1      4000
# [2025.08.21 16:20:09.093] INFO     ─────────────────────────────────────────────────────────────────────────
# [2025.08.21 16:20:09.093] INFO      5      device_shfqc     0         19            0           1      4000
# [2025.08.21 16:20:09.093] INFO     ─────────────────────────────────────────────────────────────────────────
# [2025.08.21 16:20:09.093] INFO      6      device_shfqc     0         19            0           1      4000
# [2025.08.21 16:20:09.093] INFO     ─────────────────────────────────────────────────────────────────────────
# [2025.08.21 16:20:09.094] INFO      7      device_shfqc     0         19            0           1      4000
# [2025.08.21 16:20:09.094] INFO     ─────────────────────────────────────────────────────────────────────────
# [2025.08.21 16:20:09.094] INFO      8      device_shfqc     0         19            0           1      4000
# [2025.08.21 16:20:09.094] INFO     ─────────────────────────────────────────────────────────────────────────
# [2025.08.21 16:20:09.094] INFO      9      device_shfqc     0         19            0           1      4000
# [2025.08.21 16:20:09.094] INFO     ─────────────────────────────────────────────────────────────────────────
# [2025.08.21 16:20:09.095] INFO      10     device_shfqc     0         19            0           1      4000
# [2025.08.21 16:20:09.095] INFO     ─────────────────────────────────────────────────────────────────────────
# [2025.08.21 16:20:09.095] INFO             TOTAL                     209            0                 44000
# [2025.08.21 16:20:09.095] INFO     ─────────────────────────────────────────────────────────────────────────
# [2025.08.21 16:20:09.099] INFO    Finished LabOne Q Compiler run.
# [2025.08.21 16:20:09.105] INFO    Starting near-time execution...
# [2025.08.21 16:20:09.135] INFO    Finished near-time execution.

# %%
plot_simulation(instance_PunchOut.compiled_exp_instance, 0, 100e-6)

# %%
data_punchout.waves
# Out:
# {'p_2000_readout_pulse_00_a0100_l2000_sc0_ap0000_9e3121d.wave': CodegenWaveform(samples=array([0.10000002+0.j, 0.10000002+0.j, 0.10000002+0.j, ...,
#         0.10000002+0.j, 0.10000002+0.j, 0.10000002+0.j], shape=(2000,)), hold_start=None, hold_length=None, downsampling_factor=None),
#  'p_2000_readout_pulse_00_a0160_l2000_sc0_ap0000_2f3155c.wave': CodegenWaveform(samples=array([0.16000003+0.j, 0.16000003+0.j, 0.16000003+0.j, ...,
#         0.16000003+0.j, 0.16000003+0.j, 0.16000003+0.j], shape=(2000,)), hold_start=None, hold_length=None, downsampling_factor=None),
#  'p_2000_readout_pulse_00_a0220_l2000_sc0_ap0000_982d4e9.wave': CodegenWaveform(samples=array([0.22000003+0.j, 0.22000003+0.j, 0.22000003+0.j, ...,
#         0.22000003+0.j, 0.22000003+0.j, 0.22000003+0.j], shape=(2000,)), hold_start=None, hold_length=None, downsampling_factor=None),
#  'p_2000_readout_pulse_00_a0280_l2000_sc0_ap0000_7f3184f.wave': CodegenWaveform(samples=array([0.27999997+0.j, 0.27999997+0.j, 0.27999997+0.j, ...,
#         0.27999997+0.j, 0.27999997+0.j, 0.27999997+0.j], shape=(2000,)), hold_start=None, hold_length=None, downsampling_factor=None),
#  'p_2000_readout_pulse_00_a0340_l2000_sc0_ap0000_ee0e48f.wave': CodegenWaveform(samples=array([0.33999997+0.j, 0.33999997+0.j, 0.33999997+0.j, ...,
#         0.33999997+0.j, 0.33999997+0.j, 0.33999997+0.j], shape=(2000,)), hold_start=None, hold_length=None, downsampling_factor=None),
#  'p_2000_readout_pulse_00_a0400_l2000_sc0_ap0000_e5956b6.wave': CodegenWaveform(samples=array([0.39999998+0.j, 0.39999998+0.j, 0.39999998+0.j, ...,
#         0.39999998+0.j, 0.39999998+0.j, 0.39999998+0.j], shape=(2000,)), hold_start=None, hold_length=None, downsampling_factor=None),
#  'p_2000_readout_pulse_00_a0460_l2000_sc0_ap0000_aa3a746.wave': CodegenWaveform(samples=array([0.45999998+0.j, 0.45999998+0.j, 0.45999998+0.j, ...,
#         0.45999998+0.j, 0.45999998+0.j, 0.45999998+0.j], shape=(2000,)), hold_start=None, hold_length=None, downsampling_factor=None),
#  'p_2000_readout_pulse_00_a0520_l2000_sc0_ap0000_0f8fa49.wave': CodegenWaveform(samples=array([0.51999998+0.j, 0.51999998+0.j, 0.51999998+0.j, ...,
#         0.51999998+0.j, 0.51999998+0.j, 0.51999998+0.j], shape=(2000,)), hold_start=None, hold_length=None, downsampling_factor=None),
#  'p_2000_readout_pulse_00_a0580_l2000_sc0_ap0000_dee7687.wave': CodegenWaveform(samples=array([0.57999998+0.j, 0.57999998+0.j, 0.57999998+0.j, ...,
#         0.57999998+0.j, 0.57999998+0.j, 0.57999998+0.j], shape=(2000,)), hold_start=None, hold_length=None, downsampling_factor=None),
#  'p_2000_readout_pulse_00_a0640_l2000_sc0_ap0000_9b20c2c.wave': CodegenWaveform(samples=array([0.63999999+0.j, 0.63999999+0.j, 0.63999999+0.j, ...,
#         0.63999999+0.j, 0.63999999+0.j, 0.63999999+0.j], shape=(2000,)), hold_start=None, hold_length=None, downsampling_factor=None),
#  'p_2000_readout_pulse_00_a0700_l2000_sc0_ap0000_2ea377b.wave': CodegenWaveform(samples=array([0.69999999+0.j, 0.69999999+0.j, 0.69999999+0.j, ...,
#         0.69999999+0.j, 0.69999999+0.j, 0.69999999+0.j], shape=(2000,)), hold_start=None, hold_length=None, downsampling_factor=None)}

# %% [markdown]
# # Qubit_Spec

# %%
instance_QubitSpec = QuSpec()
data_QubitSpec = instance_QubitSpec.run_experiment()
plot_simulation(instance_QubitSpec.compiled_exp_instance, 0, 20e-6)
# Out:
# 2.57.0
# [2025.08.23 20:10:44.459] INFO    Logging initialized from [Default inline config in laboneq.laboneq_logging] logdir is /Users/runzhaoguo/Documents/MQST-UCLA/qubit_design/measurements/basic_characterization/laboneq_output/log
# [2025.08.23 20:10:44.461] INFO    VERSION: laboneq 2.57.0
# [2025.08.23 20:10:44.461] INFO    Connecting to data server at 127.0.0.1:8004
# [2025.08.23 20:10:44.463] INFO    Connected to Zurich Instruments LabOne Data Server version 25.07.0.507 at 127.0.0.1:8004
# [2025.08.23 20:10:44.465] INFO    Configuring the device setup
# [2025.08.23 20:10:44.467] INFO    The device setup is configured
# [2025.08.23 20:10:44.470] INFO    Starting LabOne Q Compiler run...
# [2025.08.23 20:10:44.631] INFO    Schedule completed. [0.160 s]
# [2025.08.23 20:10:44.812] INFO    Code generation completed for all AWGs. [0.180 s]
# [2025.08.23 20:10:44.813] INFO    Completed compilation step 1 of 1. [0.341 s]
# [2025.08.23 20:10:44.814] INFO     ─────────────────────────────────────────────────────────────────────
# [2025.08.23 20:10:44.814] INFO      Device            AWG   SeqC LOC   CT entries   Waveforms   Samples
# [2025.08.23 20:10:44.815] INFO     ─────────────────────────────────────────────────────────────────────
# [2025.08.23 20:10:44.815] INFO      device_shfqc        0          9            0           1      4000
# [2025.08.23 20:10:44.815] INFO      device_shfqc_sg     1         19            2           1      4000
# [2025.08.23 20:10:44.815] INFO     ─────────────────────────────────────────────────────────────────────
# [2025.08.23 20:10:44.815] INFO      TOTAL                         28            2                  8000
# [2025.08.23 20:10:44.816] INFO     ─────────────────────────────────────────────────────────────────────
# [2025.08.23 20:10:44.818] INFO    Finished LabOne Q Compiler run.
# [2025.08.23 20:10:44.821] INFO    Starting near-time execution...
# [2025.08.23 20:10:44.825] INFO    Finished near-time execution.
