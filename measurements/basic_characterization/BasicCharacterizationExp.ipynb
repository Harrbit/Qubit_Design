# %% [markdown]
# # Import BasicCharacterization and supporting package

# %%
from laboneq.simple import *
import matplotlib.pyplot as plt
import numpy as np
import laboneq

import sys
import os

import importlib.util

from laboneq.contrib.example_helpers.plotting.plot_helpers import plot_simulation

import sys
sys.path.append("measurements/basic_characterization/BasicCharacterization.py")
from BasicCharacterization import *

# %% [markdown]
# # Do Resonator Spectroscopy

# %%
instance_ResSpec = ResSpec()
data_ResSpec = instance_ResSpec.run_experiment()
plot_simulation(instance_ResSpec.compiled_exp_instance, 0, 100e-6)
# Out:
# 2.57.0
# [2025.08.25 10:28:53.529] INFO    Logging initialized from [Default inline config in laboneq.laboneq_logging] logdir is c:\Users\24716\Documents\code\python\qubit_design\measurements\basic_characterization\laboneq_output\log
# [2025.08.25 10:28:53.533] INFO    VERSION: laboneq 2.57.0
# [2025.08.25 10:28:53.537] INFO    Connecting to data server at 127.0.0.1:8004
# [2025.08.25 10:28:53.542] INFO    Connected to Zurich Instruments LabOne Data Server version 25.07.0.507 at 127.0.0.1:8004
# [2025.08.25 10:28:53.548] INFO    Configuring the device setup
# [2025.08.25 10:28:53.551] INFO    The device setup is configured
# [2025.08.25 10:28:53.558] INFO    Starting LabOne Q Compiler run...
# [2025.08.25 10:28:53.866] INFO    Schedule completed. [0.307 s]
# [2025.08.25 10:28:54.147] INFO    Code generation completed for all AWGs. [0.285 s]
# [2025.08.25 10:28:54.147] INFO    Completed compilation step 1 of 1. [0.593 s]
# ...

# %%
data_ResSpec
# Out:
# array([42.+42.j, 42.+42.j, 42.+42.j, ..., 42.+42.j, 42.+42.j, 42.+42.j],
#       shape=(2001,))

# %% [markdown]
# # Do Punchout

# %%
data_punchout = []
for i in np.linspace(0.1, 0.4, 61):
    instance_PunchOut = PunchOut()
    result = instance_PunchOut.run_experiment(i)
    data_punchout.append(result)
data_punchout = np.array(data_punchout)
# Out:
# 2.57.0
# [2025.08.25 10:28:54.874] INFO    Logging initialized from [Default inline config in laboneq.laboneq_logging] logdir is c:\Users\24716\Documents\code\python\qubit_design\measurements\basic_characterization\laboneq_output\log
# [2025.08.25 10:28:54.881] INFO    VERSION: laboneq 2.57.0
# [2025.08.25 10:28:54.882] INFO    Connecting to data server at 127.0.0.1:8004
# [2025.08.25 10:28:54.884] INFO    Connected to Zurich Instruments LabOne Data Server version 25.07.0.507 at 127.0.0.1:8004
# [2025.08.25 10:28:54.884] INFO    Configuring the device setup
# [2025.08.25 10:28:54.884] INFO    The device setup is configured
# [2025.08.25 10:28:54.884] INFO    Starting LabOne Q Compiler run...
# [2025.08.25 10:28:55.098] INFO    Schedule completed. [0.218 s]
# [2025.08.25 10:28:55.481] INFO    Code generation completed for all AWGs. [0.379 s]
# [2025.08.25 10:28:55.481] INFO    Completed compilation step 1 of 1. [0.600 s]
# ...

# %%
plot_simulation(instance_PunchOut.compiled_exp_instance, 0, 100e-6)

# %%
data_punchout.shape
# Out:
# (61, 2001)

# %% [markdown]
# # Qubit Spectroscopy

# %%
instance_QubitSpec = QuSpec()
data_QubitSpec = instance_QubitSpec.run_experiment()
plot_simulation(instance_QubitSpec.compiled_exp_instance, 0, 5e-6)
# Out:
# 2.57.0
# [2025.08.25 10:29:40.745] INFO    Logging initialized from [Default inline config in laboneq.laboneq_logging] logdir is c:\Users\24716\Documents\code\python\qubit_design\measurements\basic_characterization\laboneq_output\log
# [2025.08.25 10:29:40.746] INFO    VERSION: laboneq 2.57.0
# [2025.08.25 10:29:40.746] INFO    Connecting to data server at 127.0.0.1:8004
# [2025.08.25 10:29:40.746] INFO    Connected to Zurich Instruments LabOne Data Server version 25.07.0.507 at 127.0.0.1:8004
# [2025.08.25 10:29:40.746] INFO    Configuring the device setup
# [2025.08.25 10:29:40.756] INFO    The device setup is configured
# [2025.08.25 10:29:40.760] INFO    Starting LabOne Q Compiler run...
# [2025.08.25 10:29:41.076] INFO    Schedule completed. [0.314 s]
# [2025.08.25 10:29:41.294] INFO    Code generation completed for all AWGs. [0.220 s]
# [2025.08.25 10:29:41.294] INFO    Completed compilation step 1 of 1. [0.537 s]
# ...

# %% [markdown]
# # Two Tone Spectroscopy

# %%
instance_TwoToneSpec = TwoToneSpec()
data_TwoToneSpec = instance_TwoToneSpec.run_experiment()
plot_simulation(instance_TwoToneSpec.compiled_exp_instance, 0, 10e-6)
# Out:
# 2.57.0
# [2025.08.25 10:29:41.587] INFO    Logging initialized from [Default inline config in laboneq.laboneq_logging] logdir is c:\Users\24716\Documents\code\python\qubit_design\measurements\basic_characterization\laboneq_output\log
# [2025.08.25 10:29:41.593] INFO    VERSION: laboneq 2.57.0
# [2025.08.25 10:29:41.593] INFO    Connecting to data server at 127.0.0.1:8004
# [2025.08.25 10:29:41.596] INFO    Connected to Zurich Instruments LabOne Data Server version 25.07.0.507 at 127.0.0.1:8004
# [2025.08.25 10:29:41.601] INFO    Configuring the device setup
# [2025.08.25 10:29:41.602] INFO    The device setup is configured
# [2025.08.25 10:29:41.606] INFO    Starting LabOne Q Compiler run...
# [2025.08.25 10:29:41.978] INFO    Schedule completed. [0.372 s]
# [2025.08.25 10:29:42.462] INFO    Code generation completed for all AWGs. [0.487 s]
# [2025.08.25 10:29:42.462] INFO    Completed compilation step 1 of 1. [0.861 s]
# ...

# %% [markdown]
# # Time Rabi

# %%
instance_LengthRabi = TimeRabi()
data_LengthRabi = instance_LengthRabi.run_experiment()
plot_simulation(instance_LengthRabi.compiled_exp_instance, 0e-6, 150e-6)
# Out:
# 2.57.0
# [2025.08.25 10:29:42.757] INFO    Logging initialized from [Default inline config in laboneq.laboneq_logging] logdir is c:\Users\24716\Documents\code\python\qubit_design\measurements\basic_characterization\laboneq_output\log
# [2025.08.25 10:29:42.762] INFO    VERSION: laboneq 2.57.0
# [2025.08.25 10:29:42.763] INFO    Connecting to data server at 127.0.0.1:8004
# [2025.08.25 10:29:42.766] INFO    Connected to Zurich Instruments LabOne Data Server version 25.07.0.507 at 127.0.0.1:8004
# [2025.08.25 10:29:42.770] INFO    Configuring the device setup
# [2025.08.25 10:29:42.771] INFO    The device setup is configured
# [2025.08.25 10:29:42.775] INFO    Starting LabOne Q Compiler run...
# [2025.08.25 10:29:42.780] INFO    Schedule completed. [0.003 s]
# [2025.08.25 10:29:42.786] INFO    Code generation completed for all AWGs. [0.005 s]
# [2025.08.25 10:29:42.787] INFO    Completed compilation step 1 of 1. [0.010 s]
# ...

# %% [markdown]
# # Amplitude Rabi

# %%
instance_AmplitudeRabi = AmplitudeRabi()
data_AmplitudeRabi = instance_AmplitudeRabi.run_experiment()
plot_simulation(instance_AmplitudeRabi.compiled_exp_instance, 0e-6, 150e-6)
# Out:
# 2.57.0
# [2025.08.25 11:12:59.945] INFO    Logging initialized from [Default inline config in laboneq.laboneq_logging] logdir is c:\Users\24716\Documents\code\python\qubit_design\measurements\basic_characterization\laboneq_output\log
# [2025.08.25 11:12:59.945] INFO    VERSION: laboneq 2.57.0
# [2025.08.25 11:12:59.960] INFO    Connecting to data server at 127.0.0.1:8004
# [2025.08.25 11:12:59.963] INFO    Connected to Zurich Instruments LabOne Data Server version 25.07.0.507 at 127.0.0.1:8004
# [2025.08.25 11:12:59.963] INFO    Configuring the device setup
# [2025.08.25 11:12:59.963] INFO    The device setup is configured
# [2025.08.25 11:12:59.963] INFO    Starting LabOne Q Compiler run...
# [2025.08.25 11:13:00.066] INFO    Schedule completed. [0.088 s]
# [2025.08.25 11:13:00.159] INFO    Code generation completed for all AWGs. [0.101 s]
# [2025.08.25 11:13:00.159] INFO    Completed compilation step 1 of 1. [0.192 s]
# ...

# %% [markdown]
# # $T_1$

# %%
instance_T1 = T1()
data_TimeRabi = instance_T1.run_experiment()
plot_simulation(instance_T1.compiled_exp_instance, 0e-6, 120e-6)
# Out:
# 2.57.0
# [2025.08.25 10:29:43.232] INFO    Logging initialized from [Default inline config in laboneq.laboneq_logging] logdir is c:\Users\24716\Documents\code\python\qubit_design\measurements\basic_characterization\laboneq_output\log
# [2025.08.25 10:29:43.234] INFO    VERSION: laboneq 2.57.0
# [2025.08.25 10:29:43.234] INFO    Connecting to data server at 127.0.0.1:8004
# [2025.08.25 10:29:43.241] INFO    Connected to Zurich Instruments LabOne Data Server version 25.07.0.507 at 127.0.0.1:8004
# [2025.08.25 10:29:43.244] INFO    Configuring the device setup
# [2025.08.25 10:29:43.246] INFO    The device setup is configured
# [2025.08.25 10:29:43.251] INFO    Starting LabOne Q Compiler run...
# [2025.08.25 10:29:43.429] INFO    Schedule completed. [0.182 s]
# [2025.08.25 10:29:43.452] INFO    Code generation completed for all AWGs. [0.025 s]
# [2025.08.25 10:29:43.464] INFO    Completed compilation step 1 of 1. [0.210 s]
# ...

# %% [markdown]
# # $T_2^*$

# %%
instance_Ramsey = Ramsey()
data_Ramsey = instance_Ramsey.run_experiment()
plot_simulation(instance_Ramsey.compiled_exp_instance, 0e-6, 20e-6)
# Out:
# 2.57.0
# [2025.08.25 11:32:44.158] INFO    Logging initialized from [Default inline config in laboneq.laboneq_logging] logdir is c:\Users\24716\Documents\code\python\qubit_design\measurements\basic_characterization\laboneq_output\log
# [2025.08.25 11:32:44.164] INFO    VERSION: laboneq 2.57.0
# [2025.08.25 11:32:44.166] INFO    Connecting to data server at 127.0.0.1:8004
# [2025.08.25 11:32:44.170] INFO    Connected to Zurich Instruments LabOne Data Server version 25.07.0.507 at 127.0.0.1:8004
# [2025.08.25 11:32:44.174] INFO    Configuring the device setup
# [2025.08.25 11:32:44.174] INFO    The device setup is configured
# [2025.08.25 11:32:44.174] INFO    Starting LabOne Q Compiler run...
# [2025.08.25 11:32:44.403] INFO    Schedule completed. [0.223 s]
# [2025.08.25 11:32:44.533] INFO    Code generation completed for all AWGs. [0.125 s]
# [2025.08.25 11:32:44.535] INFO    Completed compilation step 1 of 1. [0.351 s]
# ...

# %% [markdown]
# # $T_2^{echo}$

# %%
instance_HanEcho = HanEcho()
data_HanEcho = instance_HanEcho.run_experiment()
plot_simulation(instance_HanEcho.compiled_exp_instance, 100e-6, 5e-6)
# Out:
# 2.57.0
# [2025.08.25 17:01:13.949] INFO    Logging initialized from [Default inline config in laboneq.laboneq_logging] logdir is c:\Users\24716\Documents\code\python\qubit_design\measurements\basic_characterization\laboneq_output\log
# [2025.08.25 17:01:13.953] INFO    VERSION: laboneq 2.57.0
# [2025.08.25 17:01:13.955] INFO    Connecting to data server at 127.0.0.1:8004
# [2025.08.25 17:01:13.958] INFO    Connected to Zurich Instruments LabOne Data Server version 25.07.0.507 at 127.0.0.1:8004
# [2025.08.25 17:01:13.961] INFO    Configuring the device setup
# [2025.08.25 17:01:13.965] INFO    The device setup is configured
# [2025.08.25 17:01:13.970] INFO    Starting LabOne Q Compiler run...
# [2025.08.25 17:01:14.083] INFO    Schedule completed. [0.111 s]
# [2025.08.25 17:01:14.317] INFO    Code generation completed for all AWGs. [0.231 s]
# [2025.08.25 17:01:14.317] INFO    Completed compilation step 1 of 1. [0.344 s]
# ...
