# %%
# Launch AEDT 2025 R2 in non-graphical mode
import ansys.aedt.core
with ansys.aedt.core.Desktop(version="2025.2", non_graphical=False, new_desktop=True, close_on_exit=True,
             student_version=True):
    circuit = ansys.aedt.core.Circuit()
    ...
    # Any error here is caught by AEDT.
    ...
# AEDT is automatically closed here.
# Out:
# FutureWarning: As part of our ongoing efforts to align with the Python Scientific Community's best practices, we are moving towards adopting SPEC 0000 (https://scientific-python.org/specs/spec-0000/). To ensure compatibility and take full advantage of the latest features and improvements, we strongly recommend updating the Python version being used.
# PyAEDT INFO: Python version 3.9.23 (main, Jun  5 2025, 13:25:08) [MSC v.1929 64 bit (AMD64)].
# PyAEDT INFO: PyAEDT version 0.17.5.
# PyAEDT INFO: Initializing new Desktop session.
# PyAEDT INFO: Log on console is enabled.
# PyAEDT INFO: Log on file C:\Users\24716\AppData\Local\Temp\pyaedt_24716_30035d82-3308-45ee-9f10-f5935e2f70e9.log is enabled.
# PyAEDT INFO: Log on AEDT is disabled.
# PyAEDT INFO: Debug logger is disabled. PyAEDT methods will not be logged.
# PyAEDT INFO: Launching PyAEDT with gRPC plugin.
# PyAEDT INFO: New AEDT session is starting on gRPC port 12928.
# PyAEDT INFO: Electronics Desktop started on gRPC port: 12928 after 26.437018632888794 seconds.
# PyAEDT INFO: AEDT installation Path D:\ansys\ANSYS Inc\ANSYS Student\v252\AnsysEM
# PyAEDT INFO: Ansoft.ElectronicsDesktop.2025.2 Student version started with process ID 23208.
# PyAEDT INFO: Python version 3.9.23 (main, Jun  5 2025, 13:25:08) [MSC v.1929 64 bit (AMD64)].
# PyAEDT INFO: PyAEDT version 0.17.5.
# PyAEDT INFO: Returning found Desktop session with PID 23208!
# PyAEDT INFO: Project Project2 has been created.
# PyAEDT INFO: No design is present. Inserting a new design.
# PyAEDT INFO: Added design 'Circuit Design_UJR' of type Circuit Design.
# PyAEDT INFO: Aedt Objects correctly read
# PyAEDT INFO: Desktop has been released and closed.
